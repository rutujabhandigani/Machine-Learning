# %%
import pandas as pd

# %%
df=pd.read_csv("Corona.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0 Province/State Country/Region          Last Update  Confirmed  \
# 0           0          Hubei          China  2020-03-17T11:53:10      67799
# 1           1            NaN          Italy  2020-03-17T18:33:02      31506
# 2           2            NaN           Iran  2020-03-17T15:13:09      16169
# 3           3            NaN          Spain  2020-03-17T20:53:02      11748
# 4           4            NaN        Germany  2020-03-17T18:53:02       9257
#
#    Deaths  Recovered  Latitude  Longitude
# 0    3111      56003   30.9756   112.2707
# 1    2503       2941   41.8719    12.5674
# 2     988       5389   32.4279    53.6880
# 3     533       1028   40.4637    -3.7492
# 4      24         67   51.1657    10.4515

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# Province/State     object
# Country/Region     object
# Last Update        object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Latitude          float64
# Longitude         float64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0         Province/State                    Country/Region  \
# 0             0                  Hubei                             China
# 1             1                    NaN                             Italy
# 2             2                    NaN                              Iran
# 3             3                    NaN                             Spain
# 4             4                    NaN                           Germany
# 5             5                    NaN                      Korea, South
# 6             6                 France                            France
# 7             7                    NaN                       Switzerland
# 8             8         United Kingdom                    United Kingdom
# 9             9               New York                                US
# 10           10            Netherlands                       Netherlands
# ...

# %%
df.isna()
# Out:
#      Unnamed: 0  Province/State  Country/Region  Last Update  Confirmed  \
# 0         False           False           False        False      False
# 1         False            True           False        False      False
# 2         False            True           False        False      False
# 3         False            True           False        False      False
# 4         False            True           False        False      False
# 5         False            True           False        False      False
# 6         False           False           False        False      False
# 7         False            True           False        False      False
# 8         False           False           False        False      False
# 9         False           False           False        False      False
# 10        False           False           False        False      False
# 11        False            True           False        False      False
# ...

# %%
df = df1
df1['Active'] = df1['Confirmed'] - df1['Deaths'] - df1['Recovered']
df1
# Out:
#      Unnamed: 0         Province/State                    Country/Region  \
# 0             0                  Hubei                             China
# 1             1                    NaN                             Italy
# 2             2                    NaN                              Iran
# 3             3                    NaN                             Spain
# 4             4                    NaN                           Germany
# 5             5                    NaN                      Korea, South
# 6             6                 France                            France
# 7             7                    NaN                       Switzerland
# 8             8         United Kingdom                    United Kingdom
# 9             9               New York                                US
# 10           10            Netherlands                       Netherlands
# 11           11                    NaN                            Norway
# ...

# %%
df_country = df1.groupby('Country/Region')[['Confirmed','Recovered','Deaths','Active']].sum()
df_country
# Out:
#                                 Confirmed  Recovered  Deaths  Active
# Country/Region
# Afghanistan                            22          1       0      21
# Albania                                55          0       1      54
# Algeria                                60         12       4      44
# Andorra                                39          1       0      38
# Antigua and Barbuda                     1          0       0       1
# Argentina                              68          3       2      63
# Armenia                                78          1       0      77
# Aruba                                   3          0       0       3
# Australia                             452         23       5     424
# Austria                              1332          1       3    1328
# Azerbaijan                             28          6       1      21
# Bahrain                               228         81       1     146
# ...

# %%
df_country_province = df1.groupby(['Country/Region','Province/State'])[['Confirmed','Recovered','Deaths','Active']].sum()
df_country_province
# Out:
#                                              Confirmed  Recovered  Deaths  \
# Country/Region Province/State
# Australia      Australian Capital Territory          2          0       0
#                From Diamond Princess                 0          0       0
#                New South Wales                     210          4       4
#                Northern Territory                    1          0       0
#                Queensland                           78          8       0
#                South Australia                      29          3       0
#                Tasmania                              7          0       0
#                Victoria                             94          8       0
#                Western Australia                    31          0       1
# Canada         Alberta                              74          0       0
#                British Columbia                    103          4       4
# ...

# %%
df_china = df1[df1['Country/Region'] =='China'].groupby(['Province/State'])[['Confirmed','Recovered','Deaths']].sum()
df_china
# Out:
#                 Confirmed  Recovered  Deaths
# Province/State
# Anhui                 990        984       6
# Beijing               456        369       8
# Chongqing             576        570       6
# Fujian                296        295       1
# Gansu                 133         91       2
# Guangdong            1364       1307       8
# Guangxi               253        248       2
# Guizhou               147        144       2
# Hainan                168        161       6
# Hebei                 318        310       6
# Heilongjiang          482        456      13
# Henan                1273       1250      22
# Hong Kong             162         88       4
# Hubei               67799      56003    3111
# Hunan                1018       1014       4
# Inner Mongolia         75         73       1
# Jiangsu               631        631       0
# Jiangxi               935        934       1
# Jilin                  93         92       1
# ...

# %%
df2=df1.sort_values(['Last Update','Country/Region','Confirmed','Deaths','Recovered'],ascending=False)
df2
# Out:
#      Unnamed: 0         Province/State                    Country/Region  \
# 187         187                Wyoming                                US
# 18           18             Washington                                US
# 55           55                Florida                                US
# 122         122                 Nevada                                US
# 154         154               Kentucky                                US
# 175         175               Delaware                                US
# 186         186           South Dakota                                US
# 185         185               Missouri                                US
# 200         200                  Idaho                                US
# 231         231           North Dakota                                US
# 268         268          West Virginia                                US
# 266         266                    NaN                        The Gambia
# ...
